# %% [markdown]
# # Hyperparameter Selection Plotter
# ##### Created by w45242hy

# %% [markdown]
# ## Install Dependency

# %%
# !pip install matplotlib torch

print(f"pip install is finished ...")

# %% [markdown]
# ## Import Dependency

# %%
import matplotlib.pyplot as plt
import torch

print(f"Import is finished ...")

# %% [markdown]
# ## Create Experiment Data

# %%
"""
In the form of {(HEAD_WEIGHTS, MODEL_NAME): experiment_output}
"""
experiment_outputs = {
    (torch.tensor([0.1000, 0.1000, 0.8000]), 'bert-base-uncased'): {
        'losses_train': {
            'loss': [0.656348803046125], 
            'loss_author': [0.47105027709363234], 
            'loss_style_similarity': [0.47400654424671773], 
            'loss_manual_stylometry': [0.7023038839990342]
        }, 
        'losses_validation': {
            'loss': [0.6507573879145562], 
            'loss_author': [0.4168124519922632], 
            'loss_style_similarity': [0.4709009957757402], 
            'loss_manual_stylometry': [0.7024825380203572], 
            'f1': [0.6436830835117773], 
            'precision': [0.9312267657992565], 
            'recall': [0.4918193717277487]
        }
    },
    (torch.tensor([0.1000, 0.1000, 0.8000]), 'bert-base-uncased'): {
        'losses_train': {
            'loss': [0.6522370585826812, 0.6295482239651459, 0.6130108743630074], 
            'loss_author': [0.4676146509332789, 0.2810730284847388, 0.14078972648874494], 
            'loss_style_similarity': [0.4742537765522246, 0.46573332773038634, 0.46381014333692966], 
            'loss_manual_stylometry': [0.6975627513257442, 0.6935844694574674, 0.6906885927612031]
        }, 
        'losses_validation': {
            'loss': [0.6439794495384744, 0.6497381694139318, 0.6593315201870938], 
            'loss_author': [0.4134036485660583, 0.49296331532458043, 0.6066671504262597], 
            'loss_style_similarity': [0.47094917963159844, 0.46882970171405913, 0.4671702364340742], 
            'loss_manual_stylometry': [0.6944301946366087, 0.6919485672991327, 0.6899347092877043], 
            'f1': [0.6461406884755185, 0.7048476170996113, 0.7717269675494218], 
            'precision': [0.932140653917335, 0.9399890889252591, 0.8972246313963573], 
            'recall': [0.4944371727748691, 0.5638089005235603, 0.6770287958115183]
        }
    },
    (torch.tensor([0.1000, 0.8000, 0.1000]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.49384357038609406, 0.4683680852047271, 0.4504194942958377], 
            'loss_author': [0.5269581315590551, 0.36292101808444216, 0.23579817146485396], 
            'loss_style_similarity': [0.46438486142842855, 0.45344017208036447, 0.4472039829318722], 
            'loss_manual_stylometry': [0.6963985994182251, 0.6932383733629076, 0.6907648179266188]
        }, 
        'losses_validation': {
            'loss': [0.48559686525705015, 0.4903042619215681, 0.5083609965253384], 
            'loss_author': [0.45791126795588655, 0.482816440469407, 0.5138551941577424], 
            'loss_style_similarity': [0.46298146184454575, 0.4660141479144705, 0.4849072591738498], 
            'loss_manual_stylometry': [0.6942056154317044, 0.6921129458128138, 0.6904966434899796], 
            'f1': [0.2711386696730553, 0.2600795002839296, 0.24778254649499282], 
            'precision': [0.9776422764227642, 0.9828326180257511, 0.9863325740318907], 
            'recall': [0.1573952879581152, 0.149869109947644, 0.14168848167539266]
        }
    },
    (torch.tensor([0.2500, 0.2500, 0.5000]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5798117134168193], 
            'loss_author': [0.4497284750212674], 
            'loss_style_similarity': [0.4753393569133348], 
            'loss_manual_stylometry': [0.6970895113492453]
        }, 
        'losses_validation': {
            'loss': [0.5657090392518551], 
            'loss_author': [0.3890712350765441], 
            'loss_style_similarity': [0.47331247447018926], 
            'loss_manual_stylometry': [0.7002262222640058], 
            'f1': [0.6841776110068793], 
            'precision': [0.9425617461229179], 
            'recall': [0.536976439790576]
        }
    }, 
    (torch.tensor([0.2500, 0.5000, 0.2500]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5259907859963951], 
            'loss_author': [0.46429316114841235], 
            'loss_style_similarity': [0.47218578933151784], 
            'loss_manual_stylometry': [0.6952984070888272]
        }, 
        'losses_validation': {
            'loss': [0.5093903172206371], 
            'loss_author': [0.403021957011933], 
            'loss_style_similarity': [0.46990386491760294], 
            'loss_manual_stylometry': [0.6947315852058694], 
            'f1': [0.6201688138605065], 
            'precision': [0.9654218533886584], 
            'recall': [0.4568062827225131]
        }
    }, 
    (torch.tensor([0.5000, 0.2500, 0.2500]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5176317831846299], 
            'loss_author': [0.44638245337194316], 
            'loss_style_similarity': [0.4800005172620769], 
            'loss_manual_stylometry': [0.6977617136996102]
        }, 
        'losses_validation': {
            'loss': [0.4852057137387864], 
            'loss_author': [0.3839713877185862], 
            'loss_style_similarity': [0.4761090416540491], 
            'loss_manual_stylometry': [0.6967710430951829], 
            'f1': [0.7603686635944701], 
            'precision': [0.9200743494423792], 
            'recall': [0.6479057591623036]
        }
    },
    (torch.tensor([0.2500, 0.2500, 0.5000]), 'bert-base-uncased'): {
        'losses_train': {
            'loss': [0.5852761958484296, 0.5365654830648391, 0.4990029149102392, 0.47940408434994797, 0.4713346686007248],
            'loss_author': [0.4651952384177733, 0.28806122322997973, 0.1462299626555587, 0.07498459494133757, 0.04860459017611531],
            'loss_style_similarity': [0.47388552163762077, 0.4660228833694149, 0.4641848573530162, 0.46227060275635234, 0.4606769663040285],
            'loss_manual_stylometry': [0.7010120098237638, 0.6960889130002923, 0.6927984179583965, 0.6901805700941218, 0.6880285598475624]
        },
        'losses_validation': {
            'loss': [0.5701838287901371, 0.5776223833573625, 0.6054637860110466, 0.6478387518449032, 0.6538895528684271],
            'loss_author': [0.4143279287171491, 0.4532879293361243, 0.5700621263302387, 0.7430114203846042, 0.7715349625845618],
            'loss_style_similarity': [0.4706973920160152, 0.46784260076411227, 0.46699810345122156, 0.46717226410165746, 0.4657589295443068],
            'loss_manual_stylometry': [0.6978549938252632, 0.6946794999406692, 0.6923974546346259, 0.6905856604905839, 0.6891321619140341],
            'f1': [0.6743989877688739, 0.7310756972111555, 0.8071764500958021, 0.7934959349593496, 0.7787610619469026],
            'precision': [0.9483985765124555, 0.9343177189409368, 0.8629422718808194, 0.8858410649455426, 0.9170731707317074],
            'recall': [0.5232329842931938, 0.6004581151832461, 0.7581806282722513, 0.7185863874345549, 0.6767015706806283]
        }
    },
    (torch.tensor([0.2500, 0.2500, 0.5000]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5798117134168193], 
            'loss_author': [0.4497284750212674], 
            'loss_style_similarity': [0.4753393569133348], 
            'loss_manual_stylometry': [0.6970895113492453]
        }, 
        'losses_validation': {
            'loss': [0.5657090392518551], 
            'loss_author': [0.3890712350765441], 
            'loss_style_similarity': [0.47331247447018926], 
            'loss_manual_stylometry': [0.7002262222640058], 
            'f1': [0.6841776110068793], 
            'precision': [0.9425617461229179], 
            'recall': [0.536976439790576]
        }
    }, 
    (torch.tensor([0.2500, 0.5000, 0.2500]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5259907859963951], 
            'loss_author': [0.46429316114841235], 
            'loss_style_similarity': [0.47218578933151784], 
            'loss_manual_stylometry': [0.6952984070888272]
        }, 
        'losses_validation': {
            'loss': [0.5093903172206371], 
            'loss_author': [0.403021957011933], 
            'loss_style_similarity': [0.46990386491760294], 
            'loss_manual_stylometry': [0.6947315852058694], 
            'f1': [0.6201688138605065], 
            'precision': [0.9654218533886584], 
            'recall': [0.4568062827225131]
        }
    }, 
    (torch.tensor([0.5000, 0.2500, 0.2500]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5176317831846299], 
            'loss_author': [0.44638245337194316], 
            'loss_style_similarity': [0.4800005172620769], 
            'loss_manual_stylometry': [0.6977617136996102]
        }, 
        'losses_validation': {
            'loss': [0.4852057137387864], 
            'loss_author': [0.3839713877185862], 
            'loss_style_similarity': [0.4761090416540491], 
            'loss_manual_stylometry': [0.6967710430951829], 
            'f1': [0.7603686635944701], 
            'precision': [0.9200743494423792], 
            'recall': [0.6479057591623036]
        }
    },
    (torch.tensor([0.2500, 0.2500, 0.5000]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5798117134168193], 
            'loss_author': [0.4497284750212674], 
            'loss_style_similarity': [0.4753393569133348], 
            'loss_manual_stylometry': [0.6970895113492453]
        }, 
        'losses_validation': {
            'loss': [0.5657090392518551], 
            'loss_author': [0.3890712350765441], 
            'loss_style_similarity': [0.47331247447018926], 
            'loss_manual_stylometry': [0.7002262222640058], 
            'f1': [0.6841776110068793], 
            'precision': [0.9425617461229179], 
            'recall': [0.536976439790576]
        }
    }, 
    (torch.tensor([0.2500, 0.5000, 0.2500]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5259907859963951], 
            'loss_author': [0.46429316114841235], 
            'loss_style_similarity': [0.47218578933151784], 
            'loss_manual_stylometry': [0.6952984070888272]
        }, 
        'losses_validation': {
            'loss': [0.5093903172206371], 
            'loss_author': [0.403021957011933], 
            'loss_style_similarity': [0.46990386491760294], 
            'loss_manual_stylometry': [0.6947315852058694], 
            'f1': [0.6201688138605065], 
            'precision': [0.9654218533886584], 
            'recall': [0.4568062827225131]
        }
    }, 
    (torch.tensor([0.5000, 0.2500, 0.2500]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.5176317831846299], 
            'loss_author': [0.44638245337194316], 
            'loss_style_similarity': [0.4800005172620769], 
            'loss_manual_stylometry': [0.6977617136996102]
        }, 
        'losses_validation': {
            'loss': [0.4852057137387864], 
            'loss_author': [0.3839713877185862], 
            'loss_style_similarity': [0.4761090416540491], 
            'loss_manual_stylometry': [0.6967710430951829], 
            'f1': [0.7603686635944701], 
            'precision': [0.9200743494423792], 
            'recall': [0.6479057591623036]
        }
    },
    (torch.tensor([0.8000, 0.1000, 0.1000]), 'bert-base-cased'): {
        'losses_train': {
            'loss': [0.47496320048554075, 0.3288065052970692, 0.22122233112653097], 
            'loss_author': [0.44490225300951686, 0.2642890388465107, 0.13040643927039733], 
            'loss_style_similarity': [0.49150143815549435, 0.4788708109753551, 0.47678241075051053], 
            'loss_manual_stylometry': [0.6989124643581884, 0.6948818618224727, 0.6921893409970734]
        }, 
        'losses_validation': {
            'loss': [0.4255032866717653, 0.48101791176707187, 0.4929351809811085], 
            'loss_author': [0.3840136967123823, 0.4541234559518226, 0.4694658106470362], 
            'loss_style_similarity': [0.4846813941889621, 0.4811381442432708, 0.4795134024734193], 
            'loss_manual_stylometry': [0.6982418086300505, 0.696053220236555, 0.6941118351322539], 
            'f1': [0.8053808525506639, 0.8054169636493229, 0.8318821165438713], 
            'precision': [0.8639430284857571, 0.8841940532081377, 0.8518518518518519], 
            'recall': [0.7542539267015707, 0.7395287958115183, 0.81282722513089]
        }
    },
}

# %% [markdown]
# ## Plot Graph

# %%
# Set up the figure with two subplots (Loss and F1)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

for (weights, model), results in experiment_outputs.items():
    # Convert tensor to a simple list for the label
    weight_list = weights.tolist()
    label = f"{model} {weight_list}"
    
    # 1. Plot Training Loss
    train_loss = results['losses_train']['loss']
    epochs = range(1, len(train_loss) + 1)
    ax1.plot(epochs, train_loss, label=label, marker='o')

    # 2. Plot Validation F1 Score
    if 'f1' in results['losses_validation']:
        val_f1 = results['losses_validation']['f1']
        ax2.plot(epochs, val_f1, label=label, marker='s')

# Formatting the Loss plot
ax1.set_title('Training Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(fontsize='small', loc='upper right')
ax1.grid(True)

# Formatting the F1 plot
ax2.set_title('Validation F1 Score')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('F1 Score')
ax2.grid(True)

plt.tight_layout()
plt.show()
